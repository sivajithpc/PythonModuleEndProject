# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
details=pd.read_excel(r'C:\Users\Shivajith\Documents\Entri_DataFiles\myexcel.xlsx')

# %%
details
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df1=details

# %%
data=np.random.randint(150,180,458)

# %%
df1["Height"]=data

# %%
df1["Height"]=df1["Height"].astype("int64")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
b=pd.isnull(df1["Salary"])

# %%
df1[b]
# Out:
#                Name                    Team  Number Position  Age  Height  \
# 2      John Holland          Boston Celtics      30       SG   27     158
# 46      Elton Brand      Philadelphia 76ers      42       PF   37     168
# 171   Dahntay Jones     Cleveland Cavaliers      30       SG   35     177
# 264   Jordan Farmar       Memphis Grizzlies       4       PG   29     154
# 269    Ray McCallum       Memphis Grizzlies       5       PG   24     150
# 270  Xavier Munford       Memphis Grizzlies      14       PG   24     153
# 273  Alex Stepheson       Memphis Grizzlies      35       PF   28     153
# 350   Briante Weber              Miami Heat      12       PG   23     156
# 353   Dorell Wright              Miami Heat      11       SF   30     165
# 397    Axel Toupane          Denver Nuggets       6       SG   23     159
# 409      Greg Smith  Minnesota Timberwolves       4       PF   25     177
#
#      Weight                College  Salary
# ...

# %%
df2=df1

# %%
avg=df2["Salary"].mean()
avg
# Out:
# 4833969.545861297

# %%
val1=df2.loc[df2["Team"]=="Boston Celtics","Salary"].mean()
round(val1,1)
# Out:
# 4181504.9

# %%
val2=df2.loc[df2["Team"]=="Philadelphia 76ers","Salary"].mean()
round(val2,1)
# Out:
# 2213778.1

# %%
val3=df2.loc[df2["Team"]=="Cleveland Cavaliers","Salary"].mean()
round(val3,1)
# Out:
# 7642049.2

# %%
val4=df2.loc[df2["Team"]=="Memphis Grizzlies","Salary"].mean()
round(val4,1)
# Out:
# 5467920.0

# %%
val5=df2.loc[df2["Team"]=="Miami Heat","Salary"].mean()
round(val5,1)
# Out:
# 6347359.5

# %%
val6=df2.loc[df2["Team"]=="Denver Nuggets","Salary"].mean()
round(val6,1)
# Out:
# 4294423.6

# %%
val7=df2.loc[df2["Team"]=="Minnesota Timberwolves","Salary"].mean()
round(val7,1)
# Out:
# 4593053.6

# %%
df2.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
swaps = {
    "Boston Celtics":4181504.9,
    "Philadelphia 76ers": 2213778.1,
    "Cleveland Cavaliers":7642049.2,
    "Memphis Grizzlies": 5467920.0,
    "Miami Heat": 6347359.5,
    "Denver Nuggets":4294423.6,
    "Minnesota Timberwolves":4593053.6,
    'Brooklyn Nets':0,
    'New York Knicks':0,
    'Toronto Raptors':0,
    'Golden State Warriors':0,
    'Los Angeles Clippers':0, 
    'Los Angeles Lakers':0,
    'Phoenix Suns':0,
    'Sacramento Kings':0, 
    'Chicago Bulls':0,
    'Detroit Pistons':0, 
    'Indiana Pacers':0, 
    'Milwaukee Bucks':0,
    'Dallas Mavericks':0, 
    'Houston Rockets':0,
    'New Orleans Pelicans':0, 
    'San Antonio Spurs':0, 
    'Atlanta Hawks':0,
    'Charlotte Hornets':0, 
    'Orlando Magic':0,
    'Washington Wizards':0,
    'Oklahoma City Thunder':0, 
    'Portland Trail Blazers':0, 
    'Utah Jazz':0
    
    
}

# create series of substitution values
substitutions = df2.apply(
    lambda row: swaps[row["Team"]],
    axis=1,  # apply to each row
)

# fill NA in Age column with substitutions
df2["Salary"] = df2["Salary"].fillna(substitutions)

# %%
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df2.College.value_counts()
# Out:
# Kentucky           22
# Duke               20
# Kansas             19
# North Carolina     16
# UCLA               15
#                    ..
# Utah Valley         1
# Cleveland State     1
# Iowa State          1
# Florida State       1
# Baylor              1
# Name: College, Length: 118, dtype: int64

# %%
df2["College"].fillna(df2["College"].mode(),inplace=True)

# %%
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %% [markdown]
# ## Percentage splitting with respect to the total employees.

# %%
df3=pd.DataFrame(df2.Team.value_counts())

df3
# Out:
#                         Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, New Orleans Pelicans to Minnesota Timberwolves
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Team    30 non-null     int64
# dtypes: int64(1)
# memory usage: 480.0+ bytes

# %%
df3.plot.pie(y="Team",figsize=(8,8),autopct='%1.1f%%', startangle=90, radius=1.2)
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %% [markdown]
# ## Segregate the employees w.r.t different positions

# %%
df2.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
df2.Position.nunique()
# Out:
# 5

# %%
df2.groupby("Position")["Name"].nunique()
# Out:
# Position
# C      79
# PF    100
# PG     92
# SF     85
# SG    102
# Name: Name, dtype: int64

# %%
df4=pd.DataFrame(df2.groupby("Position")["Name"].nunique())

# %%
df4
# Out:
#           Name
# Position
# C           79
# PF         100
# PG          92
# SF          85
# SG         102

# %%
df4.rename(columns={"Name":"Number"},inplace=True)

# %%
df4.plot.pie(y="Number",autopct='%1.1f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left')
plt.show()

# %%
df6=df2.groupby("Position")

# %%
df6.describe()
# Out:
#          Number                                                       Age  \
#           count       mean        std  min   25%   50%   75%   max  count
# Position
# C          79.0  21.962025  16.612046  0.0  11.5  17.0  29.5  92.0   79.0
# PF        100.0  23.570000  20.107918  0.0   6.0  21.5  35.0  90.0  100.0
# PG         92.0  10.967391  11.982085  0.0   2.0   8.0  14.0  55.0   92.0
# SF         85.0  17.611765  14.904533  0.0   7.0  15.0  24.0  99.0   85.0
# SG        102.0  14.852941  11.497221  0.0   5.0  11.0  23.0  55.0  102.0
#
#                      ... Weight        Salary                              \
#                mean  ...    75%    max  count          mean           std
# Position             ...
# C         27.341772  ...  265.0  307.0   79.0  5.903511e+06  5.778432e+06
# PF        27.160000  ...  250.0  275.0  100.0  4.548356e+06  4.733511e+06
# PG        26.847826  ...  200.0  220.0   92.0  5.104349e+06  4.941761e+06
# ...

# %%
pos=df2.groupby("Position")
pos_C=pos.get_group("C")
pos_PF=pos.get_group("PF")
pos_PG=pos.get_group("PG")
pos_SF=pos.get_group("SF")
pos_SG=pos.get_group("SG")


pos_C
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 7       Kelly Olynyk          Boston Celtics      41        C   25     151
# 10   Jared Sullinger          Boston Celtics       7        C   24     150
# 14      Tyler Zeller          Boston Celtics      44        C   26     153
# 23       Brook Lopez           Brooklyn Nets      11        C   28     179
# 27        Henry Sims           Brooklyn Nets      14        C   26     166
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     164
# 447      Rudy Gobert               Utah Jazz      27        C   23     155
# 455     Tibor Pleiss               Utah Jazz      21        C   26     154
# 456      Jeff Withey               Utah Jazz      24        C   26     150
# 457         Priyanka               Utah Jazz      34        C   25     154
#
#      Weight         College      Salary
# ...

# %%
pos_PF
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 4       Jonas Jerebko          Boston Celtics       8       PF   29     177
# 5        Amir Johnson          Boston Celtics      90       PF   29     166
# 6       Jordan Mickey          Boston Celtics      55       PF   21     150
# 24   Chris McCullough           Brooklyn Nets       1       PF   21     155
# 25        Willie Reed           Brooklyn Nets      33       PF   26     173
# ..                ...                     ...     ...      ...  ...     ...
# 435    Meyers Leonard  Portland Trail Blazers      11       PF   24     161
# 441       Noah Vonleh  Portland Trail Blazers      21       PF   20     162
# 442     Trevor Booker               Utah Jazz      33       PF   28     153
# 446    Derrick Favors               Utah Jazz      15       PF   24     159
# 452        Trey Lyles               Utah Jazz      41       PF   20     177
#
#      Weight       College      Salary
# ...

# %%
pos_PG
# Out:
#               Name                    Team  Number Position  Age  Height  \
# 0    Avery Bradley          Boston Celtics       0       PG   25     157
# 8     Terry Rozier          Boston Celtics      12       PG   22     176
# 9     Marcus Smart          Boston Celtics      36       PG   22     167
# 11   Isaiah Thomas          Boston Celtics       4       PG   27     160
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32     168
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30     165
# 443     Trey Burke               Utah Jazz       3       PG   23     159
# 445     Dante Exum               Utah Jazz      11       PG   20     161
# 453   Shelvin Mack               Utah Jazz       8       PG   26     150
# 454      Raul Neto               Utah Jazz      25       PG   24     152
#
#      Weight         College     Salary
# 0       180           Texas  7730337.0
# ...

# %%
pos_SF
# Out:
#                        Name                    Team  Number Position  Age  \
# 1               Jae Crowder          Boston Celtics      99       SF   25
# 32   Thanasis Antetokounmpo         New York Knicks      43       SF   23
# 33          Carmelo Anthony         New York Knicks       7       SF   32
# 35         Cleanthony Early         New York Knicks      11       SF   25
# 42             Lance Thomas         New York Knicks      42       SF   28
# ..                      ...                     ...     ...      ...  ...
# 428         Al-Farouq Aminu  Portland Trail Blazers       8       SF   25
# 432        Maurice Harkless  Portland Trail Blazers       4       SF   23
# 448          Gordon Hayward               Utah Jazz      20       SF   26
# 450              Joe Ingles               Utah Jazz       2       SF   28
# 451           Chris Johnson               Utah Jazz      23       SF   26
#
#      Height  Weight        College      Salary
# ...

# %%
pos_SG
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     158
# 3         R.J. Hunter          Boston Celtics      28       SG   22     167
# 12        Evan Turner          Boston Celtics      11       SG   27     166
# 13        James Young          Boston Celtics      13       SG   20     155
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     157
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     168
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     170
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     160
# 444        Alec Burks               Utah Jazz      10       SG   24     164
# 449       Rodney Hood               Utah Jazz       5       SG   23     166
#
#      Weight            College     Salary
# ...

# %%
df2
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     157     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     158     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     150     203
# 454      Raul Neto       Utah Jazz      25       PG   24     152     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     154     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ## Count of different age group

# %%
df_age=df2["Age"]
df_age
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
sns.histplot(df_age,binwidth=1,binrange=(19,40))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
df2.groupby("Age")["Name"].nunique()
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# Name: Name, dtype: int64

# %%
sns.countplot(x="Age",data=df2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# ## Spending in terms of salary

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df2.sort_values(by="Salary",ascending=False).head(1)
# Out:
#             Name                Team  Number Position  Age  Height  Weight  \
# 109  Kobe Bryant  Los Angeles Lakers      24       SF   37     159     212
#
#     College      Salary
# 109     NaN  25000000.0

# %%
dfteam=pd.DataFrame(df2.groupby(['Team','Position'])['Salary'].sum())

# %%
dfteam
# Out:
#                                  Salary
# Team               Position
# Atlanta Hawks      C         22756250.0
#                    PF        23952268.0
#                    PG         9763400.0
#                    SF         6000000.0
#                    SG        10431032.0
# ...                                 ...
# Washington Wizards C         24490429.0
#                    PF        11300000.0
#                    PG        18022415.0
#                    SF        11158800.0
#                    SG        11356992.0
#
# [149 rows x 1 columns]

# %%
dfteam.sort_values(by="Salary", ascending=False)
# Out:
#                                  Salary
# Team               Position
# Los Angeles Lakers SF        31866445.0
# Miami Heat         PF        31538671.0
# Houston Rockets    SG        28122883.0
# Phoenix Suns       PG        28002998.0
# Denver Nuggets     SF        27982771.0
# ...                                 ...
# Milwaukee Bucks    SF         3104287.0
# Philadelphia 76ers SF         1845059.0
# Sacramento Kings   PF         1370152.0
# Miami Heat         C           981348.0
# Orlando Magic      SF          845059.0
#
# [149 rows x 1 columns]

# %%
dfteam.sort_values(by="Salary", ascending=False).head(1)
# Out:
#                                  Salary
# Team               Position
# Los Angeles Lakers SF        31866445.0

# %% [markdown]
# ## Age vs Salary relationship graph

# %%
df2.plot.scatter(x="Age",y="Salary")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Salary'>

# %% [markdown]
# ## Saving the datafile

# %%
df2.to_excel("employee_abccompany.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14108\550738794.py in <module>
# ----> 1 df2.to_excel("employee_abccompany.xlsx")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     886             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
# ...
